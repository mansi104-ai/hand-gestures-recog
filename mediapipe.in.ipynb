# %%
import mediapipe as mp
import numpy as np
import pyautogui
import cv2
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20036\3507319977.py in <module>
# ----> 1 import mediapipe as mp
#       2 import numpy as np
#       3 import pyautogui
#       4 import cv2
#
# c:\Users\mansi\anaconda3\lib\site-packages\mediapipe\__init__.py in <module>
#      15 from mediapipe.python import *
#      16 import mediapipe.python.solutions as solutions
# ---> 17 import mediapipe.tasks.python as tasks
#      18
#      19
#
# c:\Users\mansi\anaconda3\lib\site-packages\mediapipe\tasks\python\__init__.py in <module>
#      15 """MediaPipe Tasks API."""
#      16
# ---> 17 from . import audio
#      18 from . import components
#      19 from . import core
#
# c:\Users\mansi\anaconda3\lib\site-packages\mediapipe\tasks\python\audio\__init__.py in <module>
#      16
#      17 import mediapipe.tasks.python.audio.core
# ...
